# %% [markdown]
# <a href="https://colab.research.google.com/github/Bbasilisco/Glass-Ceiling/blob/main/GlassCeiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# # **DISPARIDADE SALARIAL ENTRE GÊNEROS NO MERCADO DE TRABALHO FORMAL BRASILEIRO**
#
# ---
#
#
#
# ## **Integrantes**: Beatriz Fonseca, Gisele dos Santos, Juliana Alves, Leila Silva, Mislian Silva e Yonah Falcão
#
# ### Fly Educação - Setembro/2026
# ---
#
# #### **Resumo**

# %% [markdown]
# ---
# ## 0. Imports
#
# Esta seção contém todas as importações de bibliotecas e métodos necessários e relevantes para a execução deste trabalho.

# %%
import os                                     # códigos de outros arquivos, módulos ou bibliotecas
import numpy as np                            # números
import pandas as pd                           # tabelas
import matplotlib.pyplot as plt               # personalização de gráficos
import seaborn as sns                         # gráficos estatísticos
from scipy.stats import mannwhitneyu          # biblioteca de estatísticas
from google.colab import auth                 # Autenticação do Google Colab para o BigQuery
auth.authenticate_user()

from google.colab import drive                # Importação do Google Drive
import gc

from sklearn.model_selection    import train_test_split, cross_val_score, GridSearchCV        #divide o dataset, avalia o desenpenho
from sklearn.pipeline           import Pipeline                                               #multiplas etapas de dados em único obj
from sklearn.compose            import ColumnTransformer                                      #pré-processamento para colunas específicas
from sklearn.impute             import SimpleImputer                                          #Trata valores ausentes substituindo-os por estratégias como Mediana
from sklearn.preprocessing      import StandardScaler, OneHotEncoder                          #normalização de variavel numerica
from sklearn.feature_selection  import SelectKBest, f_regression, mutual_info_regression, RFE #
from sklearn.dummy              import DummyRegressor                                         #modelo para comparação preve mediana
from sklearn.linear_model       import LinearRegression, Ridge, Lasso                         #modelos de regressao
from sklearn.ensemble           import RandomForestRegressor, GradientBoostingRegressor       #
from sklearn.metrics            import mean_absolute_error, mean_squared_error, r2_score      #
